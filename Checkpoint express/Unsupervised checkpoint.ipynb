# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("CC GENERAL.csv")

# %%
data.dropna()
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 4     C10005   817.714335           1.000000      16.00             16.00
# 5     C10006  1809.828751           1.000000    1333.28              0.00
# ...      ...          ...                ...        ...               ...
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
data.fillna(999, inplace=True)

# %%
data1 = data.drop(["CUST_ID","CASH_ADVANCE_TRX","CASH_ADVANCE_FREQUENCY","PURCHASES_INSTALLMENTS_FREQUENCY","ONEOFF_PURCHASES_FREQUENCY","TENURE","ONEOFF_PURCHASES","BALANCE_FREQUENCY","PURCHASES_TRX","INSTALLMENTS_PURCHASES","PRC_FULL_PAYMENT"],axis=1)

# %%
data1.head(25)
# Out:
#         BALANCE  PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  CREDIT_LIMIT  \
# 0     40.900749      95.40      0.000000             0.166667        1000.0
# 1   3202.467416       0.00   6442.945483             0.000000        7000.0
# 2   2495.148862     773.17      0.000000             1.000000        7500.0
# 3   1666.670542    1499.00    205.788017             0.083333        7500.0
# 4    817.714335      16.00      0.000000             0.083333        1200.0
# 5   1809.828751    1333.28      0.000000             0.666667        1800.0
# 6    627.260806    7091.01      0.000000             1.000000       13500.0
# 7   1823.652743     436.20      0.000000             1.000000        2300.0
# 8   1014.926473     861.49      0.000000             0.333333        7000.0
# 9    152.225975    1281.60      0.000000             0.166667       11000.0
# 10  1293.124939     920.12      0.000000             1.000000        1200.0
# ...

# %%
from pyspark.sql import SQLContext
sc = SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

spark_dff = sqlContext.createDataFrame(panada_df)

# %%
agglomerative=pd.DataFrame(clust_labels)
agglomerative
# Out:
#        0
# 0     11
# 1     11
# 2     11
# 3     11
# 4     11
# ...   ..
# 8945  11
# 8946  11
# 8947  11
# 8948  11
# 8949  11
#
# [8950 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (data ['BALANCE'] , data ["PAYMENTS"] , c= agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("BALANCE")
ax.set_ylabel("PAYMENTS")
plt.colorbar(scatter)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5,random_state=0)
kmeans.fit(data1)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
plt.scatter(data1["BALANCE"][data.label == 0],          
            data1["PAYMENTS"][data.label == 0],s=80,c='magenta',label='Careful')
plt.scatter(data1["BALANCE"][data.label == 1],
           data1["PAYMENTS"][data.label == 1],s=80,c='yellow',label='Standard')
plt.scatter(data1["BALANCE"][data.label == 2],
           data1["PAYMENTS"][data.label == 2],s=80,c='green',label='Target')
plt.scatter(data1["BALANCE"][data.label == 3], 
           data1["PAYMENTS"][data.label == 3],s=80,c='cyan',label='Careless')
plt.scatter(data1["BALANCE"][data.label == 4], 
           data1["PAYMENTS"][data.label == 4],s=80,c='burlywood',label='Sensible')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', label = 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('BALANCE')
plt.ylabel('PAYMENTS')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-15432da15360> in <module>
# ----> 1 plt.scatter(data1["BALANCE"][data.label == 0],
#       2             data1["PAYMENTS"][data.label == 0],s=80,c='magenta',label='Careful')
#       3 plt.scatter(data1["BALANCE"][data.label == 1],
#       4            data1["PAYMENTS"][data.label == 1],s=80,c='yellow',label='Standard')
#       5 plt.scatter(data1["BALANCE"][data.label == 2],
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'label'
